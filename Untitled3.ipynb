# %%
import pandas as pd                           #Data Loading
import matplotlib.pyplot as plt
import matplotlib.dates as mpdates
import os
import glob2


path = r'D:\project\Datasets\drive-download-20220405T154817Z-001'
file = glob2.glob(os.path.join(path, '*.csv'))
df_each = (pd.read_csv(i) for i in file)
df = pd.concat(df_each)
df['Dates'] = pd.to_datetime(df['Date'])
df.set_index('Dates', inplace = True)
df
# Out:
#                       SNo     Name Symbol                 Date        High  \
# Dates
# 2013-04-29 23:59:59     1  Bitcoin    BTC  2013-04-29 23:59:59  147.488007
# 2013-04-30 23:59:59     2  Bitcoin    BTC  2013-04-30 23:59:59  146.929993
# 2013-05-01 23:59:59     3  Bitcoin    BTC  2013-05-01 23:59:59  139.889999
# 2013-05-02 23:59:59     4  Bitcoin    BTC  2013-05-02 23:59:59  125.599998
# 2013-05-03 23:59:59     5  Bitcoin    BTC  2013-05-03 23:59:59  108.127998
# ...                   ...      ...    ...                  ...         ...
# 2021-07-02 23:59:59  1388     TRON    TRX  2021-07-02 23:59:59    0.066593
# 2021-07-03 23:59:59  1389     TRON    TRX  2021-07-03 23:59:59    0.067337
# 2021-07-04 23:59:59  1390     TRON    TRX  2021-07-04 23:59:59    0.068182
# 2021-07-05 23:59:59  1391     TRON    TRX  2021-07-05 23:59:59    0.067344
# 2021-07-06 23:59:59  1392     TRON    TRX  2021-07-06 23:59:59    0.066369
#
# ...

# %%
df1 = df.groupby('Symbol')

for i in df.index:
    #df['Quamtum'] = df.subtract([['Low'][i],['Low'][i+1]], axis = 'index')
    df['Quantum'] = df['Low'][i+1] - df['Low'][i]
    #print(df['Low'][i])

# %%
df_sym = df.groupby('Symbol')                #Q2
df2 = df_sym.get_group('ETH').head(15)
#print(df2)

plt.plot(df2['High'], df2.index)

# %%
df3 = df_sym.get_group('ETH').tail(10)    #Q2 contd..
plt.plot(df3['High'], df3.index)

# %%
df.info                                          #Q3
df_range = df['2020-1-1' : '2020-1-31']
df_range
#df_mon = df[df['2020'].index.month==1]
#df_mon.head(31)
df_range['Volume'].rolling(5).mean().plot()
plt.ylabel('Volume')
# Out:
# Text(0, 0.5, 'Volume')

# %%
df_marc = df['2020-1-4' : '2021-1-4']        #Q4
df_marc['Marketcap']
ax = df_marc.groupby(['Symbol'])['Marketcap'].last().sort_values(ascending=False).head(10).sort_values().plot(kind='barh')
ax.set_xlabel("Market cap")
plt.title("compare by Market Cap")
# Out:
# Text(0.5, 1.0, 'compare by Market Cap')

# %%
ax = df.groupby(['Symbol'])['Open'].last().sort_values(ascending=False).head(10).sort_values().plot(kind='bar')   #Q5
ax.set_xlabel("Coins")
ax.set_ylabel("Open")
plt.title("Initial Sales")
# Out:
# Text(0.5, 1.0, 'Initial Sales')

# %%
import matplotlib.pyplot as plt                          #Q6
from mplfinance.original_flavor import candlestick_ohlc
import pandas as pd
import matplotlib.dates as mpdates

plt.style.use('dark_background')

df6 = df[['Date', 'Open', 'High', 'Low', 'Close']]


df6['Date'] = pd.to_datetime(df6['Date'])


df6['Date'] = df6['Date'].map(mpdates.date2num)


fig, ax = plt.subplots()

candlestick_ohlc(ax, df.values, width = 0.6, colorup = 'green', colordown = 'red', alpha = 0.8)

ax.grid(True)

ax.set_xlabel('Date')
ax.set_ylabel('Price')

plt.title('Prices For the Period 01-07-2020 to 15-07-2020')

date_format = mpdates.DateFormatter('%d-%m-%Y')
ax.xaxis.set_major_formatter(date_format)
fig.autofmt_xdate()

fig.tight_layout()

plt.show()

# %%
df_sc = df['2016' : '2019']       #Q7
df_sc
# Out:
#                      SNo     Name Symbol                 Date        High  \
# Dates
# 2016-01-01 23:59:59  978  Bitcoin    BTC  2016-01-01 23:59:59  436.246002
# 2016-01-02 23:59:59  979  Bitcoin    BTC  2016-01-02 23:59:59  436.062012
# 2016-01-03 23:59:59  980  Bitcoin    BTC  2016-01-03 23:59:59  433.743011
# 2016-01-04 23:59:59  981  Bitcoin    BTC  2016-01-04 23:59:59  434.516998
# 2016-01-05 23:59:59  982  Bitcoin    BTC  2016-01-05 23:59:59  434.182007
# ...                  ...      ...    ...                  ...         ...
# 2019-12-27 23:59:59  835     TRON    TRX  2019-12-27 23:59:59    0.013454
# 2019-12-28 23:59:59  836     TRON    TRX  2019-12-28 23:59:59    0.013788
# 2019-12-29 23:59:59  837     TRON    TRX  2019-12-29 23:59:59    0.013925
# 2019-12-30 23:59:59  838     TRON    TRX  2019-12-30 23:59:59    0.013989
# 2019-12-31 23:59:59  839     TRON    TRX  2019-12-31 23:59:59    0.013490
#
#                             Low        Open       Close        Volume  \
# ...

# %%
df8= df_sc.groupby('Symbol')           #Q7 contd...
#x1 = df8.get_group('ETH')
#y1 = df8['Close']
#df8.plot.scatter(x1, y1, c='blue')
df8.get_group('ETH').plot.scatter('Close', 'SNo', c='blue')
df8.get_group('BTC').plot.scatter('Close', 'SNo', c='red')

# %%
df.describe().plot()            #Q8
